# %% [markdown]
# # Crisis Buying - Bear Market Opportunity Scanner
#
# **Strategy:**
# - ONLY activate during market corrections/bear markets
# - Buy quality stocks at panic-driven discounts
# - VIX > 25 = Opportunity (not danger)
# - Calculate intrinsic value vs current price
# - Dollar-cost average into positions
#
# **Philosophy:**
# > "Be fearful when others are greedy, and greedy when others are fearful" - Warren Buffett
#
# This is NOT for normal trading - this is for building generational wealth during crashes.

# %%
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from data_fetcher import StockDataFetcher
from indicators import sma, ema, rsi, adx, atr, cmf
from market.regime import check_market_health

plt.style.use('seaborn-v0_8-darkgrid')
# Out:
# Extended indicators module loaded

# %% [markdown]
# ## Market Regime Check - Crisis Mode
#
# This scanner ONLY works during corrections/bear markets

# %%
# Check if we're in crisis conditions
market_regime = check_market_health(verbose=True, check_breadth=False)

print("\n" + "="*60)
print("CRISIS BUYING MODE")
print("="*60)

if market_regime['regime'] in ['bear', 'correction']:
    print("STATUS: ACTIVE - Crisis conditions detected")
    print("This is when generational wealth is built.")
    CRISIS_MODE_ACTIVE = True
elif market_regime['confidence'] < 60:
    print("STATUS: WATCH - Market showing weakness")
    print("Prepare watchlist, don't deploy capital yet.")
    CRISIS_MODE_ACTIVE = False
else:
    print("STATUS: INACTIVE - Market is healthy")
    print("Use 02.1_price_finder.ipynb for normal trading.")
    CRISIS_MODE_ACTIVE = False

print("="*60)
# Out:
# /Users/jaspervalk/Documents/market-analysis/notebooks/../src/market/regime.py:36: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period=period, progress=False)
# /Users/jaspervalk/Documents/market-analysis/notebooks/../src/market/regime.py:36: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period=period, progress=False)
# /Users/jaspervalk/Documents/market-analysis/notebooks/../src/market/regime.py:36: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period=period, progress=False)
# ============================================================
# MARKET REGIME ANALYSIS
# ============================================================
#
# Regime: NEUTRAL
# Confidence: 67%
# Recommendation: BUY signals valid with caution
#
# Details:
#   [HEALTHY] SPY mixed signals
#   [HEALTHY] QQQ mixed signals
#   [UNHEALTHY] VIX 22.6 (elevated fear - caution)
# ============================================================
#
# ============================================================
# CRISIS BUYING MODE
# ============================================================
# STATUS: INACTIVE - Market is healthy
# Use 02.1_price_finder.ipynb for normal trading.
# ============================================================

# %% [markdown]
# ## Fundamental Analysis - Quality Filter
#
# In a crisis, we ONLY want the highest quality companies that will survive and thrive

# %%
def get_fundamentals(ticker):
    """Get fundamental data with focus on survival metrics"""
    try:
        stock = yf.Ticker(ticker)
        info = stock.info
        
        # Growth metrics
        revenue_growth = info.get('revenueGrowth', 0) * 100 if info.get('revenueGrowth') else None
        quarterly_revenue_growth = info.get('quarterlyRevenueGrowth', 0) * 100 if info.get('quarterlyRevenueGrowth') else None
        
        # Profitability
        gross_margin = info.get('grossMargins', 0) * 100 if info.get('grossMargins') else None
        operating_margin = info.get('operatingMargins', 0) * 100 if info.get('operatingMargins') else None
        net_margin = info.get('profitMargins', 0) * 100 if info.get('profitMargins') else None
        
        # Financial health (CRITICAL in crisis)
        current_ratio = info.get('currentRatio', None)  # > 1.5 is good
        debt_to_equity = info.get('debtToEquity', None)  # < 50 is good
        free_cash_flow = info.get('freeCashflow', None)
        
        # Valuation
        pe_ratio = info.get('trailingPE', None)
        peg_ratio = info.get('pegRatio', None)
        price_to_book = info.get('priceToBook', None)
        
        return {
            'revenue_growth_yoy': revenue_growth,
            'revenue_growth_qoq': quarterly_revenue_growth,
            'gross_margin': gross_margin,
            'operating_margin': operating_margin,
            'net_margin': net_margin,
            'current_ratio': current_ratio,
            'debt_to_equity': debt_to_equity,
            'free_cash_flow': free_cash_flow,
            'pe_ratio': pe_ratio,
            'peg_ratio': peg_ratio,
            'price_to_book': price_to_book,
            'market_cap': info.get('marketCap', 0)
        }
    except:
        return None


def calculate_quality_score(fundamentals):
    """Score based on ability to SURVIVE crisis (0-100)"""
    if not fundamentals:
        return 0, ["No fundamental data"], []
    
    score = 0
    strengths = []
    warnings = []
    
    # Financial Health (0-40 points) - MOST IMPORTANT in crisis
    current_ratio = fundamentals.get('current_ratio')
    if current_ratio:
        if current_ratio > 2.0:
            score += 20
            strengths.append(f"Excellent liquidity (CR {current_ratio:.1f})")
        elif current_ratio > 1.5:
            score += 15
            strengths.append(f"Good liquidity (CR {current_ratio:.1f})")
        elif current_ratio > 1.0:
            score += 8
            strengths.append(f"Adequate liquidity (CR {current_ratio:.1f})")
        else:
            warnings.append(f"WARNING: Low liquidity (CR {current_ratio:.1f})")
    
    debt_to_equity = fundamentals.get('debt_to_equity')
    if debt_to_equity is not None:
        if debt_to_equity < 30:
            score += 20
            strengths.append(f"Low debt (D/E {debt_to_equity:.0f})")
        elif debt_to_equity < 50:
            score += 15
            strengths.append(f"Manageable debt (D/E {debt_to_equity:.0f})")
        elif debt_to_equity < 100:
            score += 8
            warnings.append(f"Moderate debt (D/E {debt_to_equity:.0f})")
        else:
            warnings.append(f"WARNING: High debt (D/E {debt_to_equity:.0f})")
    
    # Profitability (0-30 points)
    net_margin = fundamentals.get('net_margin')
    if net_margin:
        if net_margin > 20:
            score += 15
            strengths.append(f"Highly profitable (NM {net_margin:.1f}%)")
        elif net_margin > 10:
            score += 10
            strengths.append(f"Profitable (NM {net_margin:.1f}%)")
        elif net_margin > 0:
            score += 5
            strengths.append(f"Marginally profitable (NM {net_margin:.1f}%)")
        else:
            warnings.append(f"WARNING: Unprofitable (NM {net_margin:.1f}%)")
    
    gross_margin = fundamentals.get('gross_margin')
    if gross_margin and gross_margin > 40:
        score += 15
        strengths.append(f"Strong margins (GM {gross_margin:.1f}%)")
    
    # Growth (0-30 points) - Less important in crisis
    rev_growth = fundamentals.get('revenue_growth_yoy')
    if rev_growth:
        if rev_growth > 20:
            score += 20
            strengths.append(f"Strong growth ({rev_growth:.1f}% YoY)")
        elif rev_growth > 10:
            score += 15
            strengths.append(f"Good growth ({rev_growth:.1f}% YoY)")
        elif rev_growth > 0:
            score += 10
            strengths.append(f"Growing ({rev_growth:.1f}% YoY)")
        else:
            warnings.append(f"Revenue declining ({rev_growth:.1f}% YoY)")
    
    return score, strengths, warnings


def calculate_discount(fundamentals, current_price):
    """Calculate how much stock is discounted from 'fair value'"""
    
    # Simple valuation: Compare P/E to historical average
    pe = fundamentals.get('pe_ratio')
    pb = fundamentals.get('price_to_book')
    peg = fundamentals.get('peg_ratio')
    
    discount_signals = []
    
    if pe and pe < 15:
        discount_signals.append(f"Low P/E {pe:.1f} (cheap)")
    elif pe and pe > 50:
        discount_signals.append(f"High P/E {pe:.1f} (still expensive)")
    
    if pb and pb < 2:
        discount_signals.append(f"Low P/B {pb:.1f} (value)")
    
    if peg and peg < 1:
        discount_signals.append(f"PEG {peg:.1f} (undervalued)")
    
    return discount_signals

# %% [markdown]
# ## Crisis Analysis Function

# %%
def analyze_for_crisis(ticker, fetcher):
    """Analyze stock for crisis buying opportunity"""
    print(f"\nAnalyzing {ticker}...")
    print("="*60)
    
    # Get fundamental data
    fundamentals = get_fundamentals(ticker)
    quality_score, strengths, warnings = calculate_quality_score(fundamentals)
    
    # Get technical data
    df = fetcher.fetch(ticker, period='1y')
    if df is None or len(df) < 60:
        print("Insufficient data")
        return None
    
    df['SMA_50'] = sma(df['Close'], 50)
    df['SMA_200'] = sma(df['Close'], 200)
    df['RSI'] = rsi(df['Close'], 14)
    df['ATR'] = atr(df['High'], df['Low'], df['Close'], 14)
    
    df = df.dropna()
    current = df.iloc[-1]
    current_price = current['Close']
    
    # Calculate drawdown from recent high
    high_52w = df['High'].tail(252).max()
    drawdown_pct = ((current_price - high_52w) / high_52w) * 100
    
    # Display results
    print(f"\nCURRENT PRICE: ${current_price:.2f}")
    print(f"52-Week High: ${high_52w:.2f}")
    print(f"DRAWDOWN: {drawdown_pct:.1f}% from highs")
    
    print(f"\nQUALITY SCORE: {quality_score}/100")
    if strengths:
        print("Strengths:")
        for s in strengths:
            print(f"  + {s}")
    
    if warnings:
        print("Warnings:")
        for w in warnings:
            print(f"  - {w}")
    
    # Valuation
    discount_signals = calculate_discount(fundamentals, current_price)
    if discount_signals:
        print("\nValuation:")
        for d in discount_signals:
            print(f"  {d}")
    
    print(f"\nTECHNICAL STATUS:")
    print(f"  RSI: {current['RSI']:.0f} ({'OVERSOLD' if current['RSI'] < 30 else 'EXTREME OVERSOLD' if current['RSI'] < 20 else 'Normal'})")
    print(f"  50-day MA: ${current['SMA_50']:.2f}")
    print(f"  200-day MA: ${current['SMA_200']:.2f}")
    
    # Crisis buying criteria
    # 1. Quality score > 60 (can survive)
    # 2. Down > 20% from highs (panic selling)
    # 3. RSI < 40 (oversold)
    
    can_survive = quality_score >= 60
    is_discounted = drawdown_pct < -20
    is_oversold = current['RSI'] < 40
    
    if can_survive and is_discounted and is_oversold:
        print(f"\nRECOMMENDATION: STRONG BUY (Crisis Opportunity)")
        print(f"Reason: Quality company at panic prices")
        
        # Calculate position sizing (dollar-cost average)
        entry_1 = current_price
        entry_2 = current_price * 0.90  # 10% lower
        entry_3 = current_price * 0.80  # 20% lower
        
        print(f"\nDOLLAR-COST AVERAGE PLAN:")
        print(f"  Entry 1: ${entry_1:.2f} (33% of capital) - BUY NOW")
        print(f"  Entry 2: ${entry_2:.2f} (33% of capital) - If drops 10%")
        print(f"  Entry 3: ${entry_3:.2f} (34% of capital) - If drops 20%")
        print(f"\nAverage entry: ${(entry_1 + entry_2 + entry_3) / 3:.2f}")
        
        recovery_target = high_52w
        potential_gain = ((recovery_target - current_price) / current_price) * 100
        
        print(f"\nRECOVERY POTENTIAL:")
        print(f"  Target: ${recovery_target:.2f} (52-week high)")
        print(f"  Upside: +{potential_gain:.1f}%")
        
        return {
            'ticker': ticker,
            'action': 'BUY',
            'quality_score': quality_score,
            'current_price': current_price,
            'drawdown_pct': drawdown_pct,
            'entry_1': entry_1,
            'entry_2': entry_2,
            'entry_3': entry_3,
            'upside_pct': potential_gain
        }
    
    elif can_survive and is_discounted:
        print(f"\nRECOMMENDATION: WATCH")
        print(f"Reason: Quality company but not oversold enough yet (RSI {current['RSI']:.0f})")
        
        alert_price = current_price * 0.95
        print(f"\nSET ALERT: ${alert_price:.2f} (5% lower)")
        
        return {
            'ticker': ticker,
            'action': 'WATCH',
            'quality_score': quality_score,
            'current_price': current_price,
            'alert_price': alert_price,
            'drawdown_pct': drawdown_pct
        }
    
    elif can_survive:
        print(f"\nRECOMMENDATION: WAIT")
        print(f"Reason: Quality company but not discounted enough ({drawdown_pct:.1f}% from high)")
        
        return {
            'ticker': ticker,
            'action': 'WAIT',
            'quality_score': quality_score,
            'current_price': current_price,
            'drawdown_pct': drawdown_pct
        }
    
    else:
        print(f"\nRECOMMENDATION: AVOID")
        print(f"Reason: Quality score too low ({quality_score}/100) - survival risk")
        return None

# %% [markdown]
# ## Scan Blue-Chip Stocks for Crisis Opportunities
#
# Focus on companies that will definitely survive and recover

# %%
fetcher = StockDataFetcher()

# Blue-chip + quality growth stocks
crisis_watchlist = [
    # Mega-cap tech
    'AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META', 'NVDA', 'TSLA',
    
    # Cloud/SaaS leaders
    'CRM', 'NOW', 'SNOW', 'DDOG', 'NET', 'MDB', 'CRWD',
    
    # Fintech
    'V', 'MA', 'PYPL', 'COIN', 'HOOD', 'SOFI',
    
    # E-commerce
    'SHOP', 'MELI', 'DASH',
    
    # Semiconductors
    'TSM', 'AMAT', 'LRCX', 'MRVL',
    
    # Healthcare
    'UNH', 'HIMS',
    
    # Innovation
    'PLTR', 'ADBE'
]

if not CRISIS_MODE_ACTIVE:
    print("\n" + "="*60)
    print("WARNING: Crisis mode is NOT active")
    print("Running analysis for educational purposes only.")
    print("DO NOT deploy capital until crisis conditions exist.")
    print("="*60 + "\n")

results = []
for ticker in crisis_watchlist:
    result = analyze_for_crisis(ticker, fetcher)
    if result:
        results.append(result)

# Summary
print("\n" + "="*60)
print("CRISIS BUYING SUMMARY")
print("="*60)

buy_now = [r for r in results if r['action'] == 'BUY']
watch = [r for r in results if r['action'] == 'WATCH']
wait = [r for r in results if r['action'] == 'WAIT']

if buy_now:
    print(f"\nSTRONG BUY - Crisis Opportunities ({len(buy_now)} stocks):")
    print("Quality companies at panic prices - Start DCA now\n")
    buy_sorted = sorted(buy_now, key=lambda x: x['upside_pct'], reverse=True)
    for r in buy_sorted:
        print(f"  {r['ticker']}: ${r['current_price']:.2f} (Down {r['drawdown_pct']:.1f}%) - Upside: +{r['upside_pct']:.1f}% [Quality: {r['quality_score']}]")
        print(f"    DCA: ${r['entry_1']:.2f} -> ${r['entry_2']:.2f} -> ${r['entry_3']:.2f}")

if watch:
    print(f"\nWATCH - Getting close ({len(watch)} stocks):")
    for r in watch:
        print(f"  {r['ticker']}: ${r['current_price']:.2f} -> Alert: ${r['alert_price']:.2f} [Quality: {r['quality_score']}]")

if wait:
    print(f"\nWAIT - Not discounted enough ({len(wait)} stocks):")
    for r in wait:
        print(f"  {r['ticker']}: ${r['current_price']:.2f} (Down {r['drawdown_pct']:.1f}%) [Quality: {r['quality_score']}]")

print("\n" + "="*60)
print("CRISIS BUYING RULES:")
print("="*60)
print("1. ONLY buy during bear markets/corrections")
print("2. ONLY buy quality companies (score > 60)")
print("3. ALWAYS dollar-cost average (3 entries)")
print("4. Hold for 2-5 years (recovery + growth)")
print("5. Size positions: 5-10% of portfolio max")
print("="*60)
# Out:
# ============================================================
# WARNING: Crisis mode is NOT active
# Running analysis for educational purposes only.
# DO NOT deploy capital until crisis conditions exist.
# ============================================================
#
#
# Analyzing AAPL...
# ============================================================
# Fetching AAPL data...
# Got 250 days of data
#
# CURRENT PRICE: $270.84
# 52-Week High: $277.05
# DRAWDOWN: -2.2% from highs
#
# QUALITY SCORE: 40/100
# Strengths:
#   + Highly profitable (NM 26.9%)
#   + Strong margins (GM 46.9%)
#   + Growing (7.9% YoY)
# Warnings:
#   - WARNING: Low liquidity (CR 0.9)
#   - WARNING: High debt (D/E 152)
#
# TECHNICAL STATUS:
#   RSI: 66 (Normal)
#   50-day MA: $255.00
#   200-day MA: $224.71
#
# RECOMMENDATION: AVOID
# Reason: Quality score too low (40/100) - survival risk
#
# Analyzing MSFT...
# ============================================================
# Fetching MSFT data...
# Got 250 days of data
#
# CURRENT PRICE: $502.05
# 52-Week High: $553.72
# DRAWDOWN: -9.3% from highs
#
# QUALITY SCORE: 68/100
# Strengths:
#   + Adequate liquidity (CR 1.4)
#   + Manageable debt (D/E 33)
#   + Highly profitable (NM 35.7%)
#   + Strong margins (GM 68.8%)
#   + Good growth (18.4% YoY)
#
# TECHNICAL STATUS:
#   RSI: 38 (Normal)
#   50-day MA: $513.93
#   200-day MA: $463.39
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-9.3% from high)
#
# Analyzing GOOGL...
# ============================================================
# Fetching GOOGL data...
# Got 250 days of data
#
# CURRENT PRICE: $274.83
# 52-Week High: $292.01
# DRAWDOWN: -5.9% from highs
#
# QUALITY SCORE: 80/100
# Strengths:
#   + Good liquidity (CR 1.7)
#   + Low debt (D/E 11)
#   + Highly profitable (NM 32.2%)
#   + Strong margins (GM 59.2%)
#   + Good growth (15.9% YoY)
#
# TECHNICAL STATUS:
#   RSI: 60 (Normal)
#   50-day MA: $256.33
#   200-day MA: $196.42
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-5.9% from high)
#
# Analyzing AMZN...
# ============================================================
# Fetching AMZN data...
# Got 250 days of data
#
# CURRENT PRICE: $234.33
# 52-Week High: $258.60
# DRAWDOWN: -9.4% from highs
#
# QUALITY SCORE: 63/100
# Strengths:
#   + Adequate liquidity (CR 1.0)
#   + Manageable debt (D/E 43)
#   + Profitable (NM 11.1%)
#   + Strong margins (GM 50.0%)
#   + Good growth (13.4% YoY)
#
# TECHNICAL STATUS:
#   RSI: 56 (Normal)
#   50-day MA: $228.59
#   200-day MA: $215.07
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-9.4% from high)
#
# Analyzing META...
# ============================================================
# Fetching META data...
# Got 250 days of data
#
# CURRENT PRICE: $600.72
# 52-Week High: $790.27
# DRAWDOWN: -24.0% from highs
#
# QUALITY SCORE: 85/100
# Strengths:
#   + Good liquidity (CR 2.0)
#   + Low debt (D/E 26)
#   + Highly profitable (NM 30.9%)
#   + Strong margins (GM 82.0%)
#   + Strong growth (26.2% YoY)
#
# TECHNICAL STATUS:
#   RSI: 17 (OVERSOLD)
#   50-day MA: $716.29
#   200-day MA: $677.12
#
# RECOMMENDATION: STRONG BUY (Crisis Opportunity)
# Reason: Quality company at panic prices
#
# DOLLAR-COST AVERAGE PLAN:
#   Entry 1: $600.72 (33% of capital) - BUY NOW
#   Entry 2: $540.65 (33% of capital) - If drops 10%
#   Entry 3: $480.58 (34% of capital) - If drops 20%
#
# Average entry: $540.65
#
# RECOVERY POTENTIAL:
#   Target: $790.27 (52-week high)
#   Upside: +31.6%
#
# Analyzing NVDA...
# ============================================================
# Fetching NVDA data...
# Got 250 days of data
#
# CURRENT PRICE: $186.73
# 52-Week High: $212.19
# DRAWDOWN: -12.0% from highs
#
# QUALITY SCORE: 90/100
# Strengths:
#   + Excellent liquidity (CR 4.2)
#   + Low debt (D/E 11)
#   + Highly profitable (NM 52.4%)
#   + Strong margins (GM 69.8%)
#   + Strong growth (55.6% YoY)
#
# Valuation:
#   High P/E 53.2 (still expensive)
#
# TECHNICAL STATUS:
#   RSI: 50 (Normal)
#   50-day MA: $185.14
#   200-day MA: $150.85
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-12.0% from high)
#
# Analyzing TSLA...
# ============================================================
# Fetching TSLA data...
# Got 250 days of data
#
# CURRENT PRICE: $394.34
# 52-Week High: $474.07
# DRAWDOWN: -16.8% from highs
#
# QUALITY SCORE: 60/100
# Strengths:
#   + Excellent liquidity (CR 2.1)
#   + Low debt (D/E 17)
#   + Marginally profitable (NM 5.3%)
#   + Good growth (11.6% YoY)
#
# Valuation:
#   High P/E 270.1 (still expensive)
#
# TECHNICAL STATUS:
#   RSI: 41 (Normal)
#   50-day MA: $428.44
#   200-day MA: $338.44
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-16.8% from high)
#
# Analyzing CRM...
# ============================================================
# Fetching CRM data...
# Got 250 days of data
#
# CURRENT PRICE: $238.10
# 52-Week High: $267.13
# DRAWDOWN: -10.9% from highs
#
# QUALITY SCORE: 63/100
# Strengths:
#   + Adequate liquidity (CR 1.1)
#   + Low debt (D/E 19)
#   + Profitable (NM 16.9%)
#   + Strong margins (GM 77.6%)
#   + Growing (9.8% YoY)
#
# TECHNICAL STATUS:
#   RSI: 34 (Normal)
#   50-day MA: $246.56
#   200-day MA: $266.00
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-10.9% from high)
#
# Analyzing NOW...
# ============================================================
# Fetching NOW data...
# Got 250 days of data
#
# CURRENT PRICE: $842.94
# 52-Week High: $973.63
# DRAWDOWN: -13.4% from highs
#
# QUALITY SCORE: 73/100
# Strengths:
#   + Adequate liquidity (CR 1.1)
#   + Low debt (D/E 21)
#   + Profitable (NM 13.7%)
#   + Strong margins (GM 78.1%)
#   + Strong growth (21.8% YoY)
#
# Valuation:
#   High P/E 101.7 (still expensive)
#
# TECHNICAL STATUS:
#   RSI: 27 (OVERSOLD)
#   50-day MA: $915.99
#   200-day MA: $927.70
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-13.4% from high)
#
# Analyzing SNOW...
# ============================================================
# Fetching SNOW data...
# Got 250 days of data
#
# CURRENT PRICE: $252.87
# 52-Week High: $280.67
# DRAWDOWN: -9.9% from highs
#
# QUALITY SCORE: 43/100
# Strengths:
#   + Adequate liquidity (CR 1.5)
#   + Strong margins (GM 66.8%)
#   + Strong growth (31.8% YoY)
# Warnings:
#   - WARNING: High debt (D/E 113)
#   - WARNING: Unprofitable (NM -33.5%)
#
# TECHNICAL STATUS:
#   RSI: 46 (Normal)
#   50-day MA: $243.25
#   200-day MA: $201.11
#
# RECOMMENDATION: AVOID
# Reason: Quality score too low (43/100) - survival risk
#
# Analyzing DDOG...
# ============================================================
# Fetching DDOG data...
# Got 250 days of data
#
# CURRENT PRICE: $183.45
# 52-Week High: $201.69
# DRAWDOWN: -9.0% from highs
#
# QUALITY SCORE: 75/100
# Strengths:
#   + Excellent liquidity (CR 3.7)
#   + Manageable debt (D/E 37)
#   + Marginally profitable (NM 3.3%)
#   + Strong margins (GM 80.0%)
#   + Strong growth (28.4% YoY)
#
# Valuation:
#   High P/E 591.8 (still expensive)
#
# TECHNICAL STATUS:
#   RSI: 67 (Normal)
#   50-day MA: $154.60
#   200-day MA: $129.70
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-9.0% from high)
#
# Analyzing NET...
# ============================================================
# Fetching NET data...
# Got 250 days of data
#
# CURRENT PRICE: $209.04
# 52-Week High: $260.00
# DRAWDOWN: -19.6% from highs
#
# QUALITY SCORE: 55/100
# Strengths:
#   + Excellent liquidity (CR 2.0)
#   + Strong margins (GM 75.2%)
#   + Strong growth (30.7% YoY)
# Warnings:
#   - WARNING: High debt (D/E 260)
#   - WARNING: Unprofitable (NM -5.1%)
#
# TECHNICAL STATUS:
#   RSI: 46 (Normal)
#   50-day MA: $221.96
#   200-day MA: $175.03
#
# RECOMMENDATION: AVOID
# Reason: Quality score too low (55/100) - survival risk
#
# Analyzing MDB...
# ============================================================
# Fetching MDB data...
# Got 250 days of data
#
# CURRENT PRICE: $346.97
# 52-Week High: $385.44
# DRAWDOWN: -10.0% from highs
#
# QUALITY SCORE: 75/100
# Strengths:
#   + Excellent liquidity (CR 5.7)
#   + Low debt (D/E 2)
#   + Strong margins (GM 72.3%)
#   + Strong growth (23.7% YoY)
# Warnings:
#   - WARNING: Unprofitable (NM -3.5%)
#
# TECHNICAL STATUS:
#   RSI: 56 (Normal)
#   50-day MA: $331.87
#   200-day MA: $243.69
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-10.0% from high)
#
# Analyzing CRWD...
# ============================================================
# Fetching CRWD data...
# Got 250 days of data
#
# CURRENT PRICE: $525.81
# 52-Week High: $566.90
# DRAWDOWN: -7.2% from highs
#
# QUALITY SCORE: 70/100
# Strengths:
#   + Good liquidity (CR 1.9)
#   + Low debt (D/E 21)
#   + Strong margins (GM 74.2%)
#   + Strong growth (21.3% YoY)
# Warnings:
#   - WARNING: Unprofitable (NM -6.8%)
#
# TECHNICAL STATUS:
#   RSI: 49 (Normal)
#   50-day MA: $497.27
#   200-day MA: $444.17
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-7.2% from high)
#
# Analyzing V...
# ============================================================
# Fetching V data...
# Got 250 days of data
#
# CURRENT PRICE: $332.95
# 52-Week High: $354.30
# DRAWDOWN: -6.0% from highs
#
# QUALITY SCORE: 61/100
# Strengths:
#   + Adequate liquidity (CR 1.1)
#   + Highly profitable (NM 50.1%)
#   + Strong margins (GM 97.8%)
#   + Good growth (11.5% YoY)
# Warnings:
#   - Moderate debt (D/E 69)
#
# TECHNICAL STATUS:
#   RSI: 32 (Normal)
#   50-day MA: $341.77
#   200-day MA: $345.19
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-6.0% from high)
#
# Analyzing MA...
# ============================================================
# Fetching MA data...
# Got 250 days of data
#
# CURRENT PRICE: $551.54
# 52-Week High: $600.83
# DRAWDOWN: -8.2% from highs
#
# QUALITY SCORE: 53/100
# Strengths:
#   + Adequate liquidity (CR 1.1)
#   + Highly profitable (NM 45.3%)
#   + Strong margins (GM 100.0%)
#   + Good growth (16.7% YoY)
# Warnings:
#   - WARNING: High debt (D/E 240)
#
# TECHNICAL STATUS:
#   RSI: 31 (Normal)
#   50-day MA: $568.81
#   200-day MA: $560.19
#
# RECOMMENDATION: AVOID
# Reason: Quality score too low (53/100) - survival risk
#
# Analyzing PYPL...
# ============================================================
# Fetching PYPL data...
# Got 250 days of data
#
# CURRENT PRICE: $63.57
# 52-Week High: $79.21
# DRAWDOWN: -19.7% from highs
#
# QUALITY SCORE: 51/100
# Strengths:
#   + Adequate liquidity (CR 1.3)
#   + Profitable (NM 15.0%)
#   + Strong margins (GM 41.6%)
#   + Growing (7.3% YoY)
# Warnings:
#   - Moderate debt (D/E 60)
#
# Valuation:
#   Low P/E 12.8 (cheap)
#
# TECHNICAL STATUS:
#   RSI: 36 (Normal)
#   50-day MA: $68.51
#   200-day MA: $70.25
#
# RECOMMENDATION: AVOID
# Reason: Quality score too low (51/100) - survival risk
#
# Analyzing COIN...
# ============================================================
# Fetching COIN data...
# Got 250 days of data
#
# CURRENT PRICE: $278.10
# 52-Week High: $402.16
# DRAWDOWN: -30.8% from highs
#
# QUALITY SCORE: 85/100
# Strengths:
#   + Excellent liquidity (CR 2.4)
#   + Manageable debt (D/E 49)
#   + Highly profitable (NM 43.7%)
#   + Strong margins (GM 84.8%)
#   + Strong growth (58.9% YoY)
#
# TECHNICAL STATUS:
#   RSI: 30 (OVERSOLD)
#   50-day MA: $333.67
#   200-day MA: $283.03
#
# RECOMMENDATION: STRONG BUY (Crisis Opportunity)
# Reason: Quality company at panic prices
#
# DOLLAR-COST AVERAGE PLAN:
#   Entry 1: $278.10 (33% of capital) - BUY NOW
#   Entry 2: $250.29 (33% of capital) - If drops 10%
#   Entry 3: $222.48 (34% of capital) - If drops 20%
#
# Average entry: $250.29
#
# RECOVERY POTENTIAL:
#   Target: $402.16 (52-week high)
#   Upside: +44.6%
#
# Analyzing HOOD...
# ============================================================
# Fetching HOOD data...
# Got 250 days of data
#
# CURRENT PRICE: $120.42
# 52-Week High: $153.86
# DRAWDOWN: -21.7% from highs
#
# QUALITY SCORE: 58/100
# Strengths:
#   + Adequate liquidity (CR 1.1)
#   + Highly profitable (NM 52.2%)
#   + Strong margins (GM 92.2%)
#   + Strong growth (100.0% YoY)
# Warnings:
#   - WARNING: High debt (D/E 189)
#
# Valuation:
#   High P/E 50.4 (still expensive)
#
# TECHNICAL STATUS:
#   RSI: 38 (Normal)
#   50-day MA: $132.36
#   200-day MA: $85.59
#
# RECOMMENDATION: AVOID
# Reason: Quality score too low (58/100) - survival risk
#
# Analyzing SOFI...
# ============================================================
# Fetching SOFI data...
# Got 250 days of data
#
# CURRENT PRICE: $28.37
# 52-Week High: $32.73
# DRAWDOWN: -13.3% from highs
#
# QUALITY SCORE: 68/100
# Strengths:
#   + Adequate liquidity (CR 1.1)
#   + Manageable debt (D/E 32)
#   + Profitable (NM 19.5%)
#   + Strong margins (GM 82.5%)
#   + Strong growth (37.8% YoY)
#
# Valuation:
#   High P/E 50.7 (still expensive)
#
# TECHNICAL STATUS:
#   RSI: 48 (Normal)
#   50-day MA: $28.07
#   200-day MA: $19.14
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-13.3% from high)
#
# Analyzing SHOP...
# ============================================================
# Fetching SHOP data...
# Got 250 days of data
#
# CURRENT PRICE: $143.63
# 52-Week High: $182.19
# DRAWDOWN: -21.2% from highs
#
# QUALITY SCORE: 85/100
# Strengths:
#   + Excellent liquidity (CR 3.9)
#   + Low debt (D/E 9)
#   + Profitable (NM 16.7%)
#   + Strong margins (GM 48.7%)
#   + Strong growth (31.5% YoY)
#
# Valuation:
#   High P/E 105.6 (still expensive)
#
# TECHNICAL STATUS:
#   RSI: 25 (OVERSOLD)
#   50-day MA: $156.64
#   200-day MA: $123.32
#
# RECOMMENDATION: STRONG BUY (Crisis Opportunity)
# Reason: Quality company at panic prices
#
# DOLLAR-COST AVERAGE PLAN:
#   Entry 1: $143.63 (33% of capital) - BUY NOW
#   Entry 2: $129.27 (33% of capital) - If drops 10%
#   Entry 3: $114.90 (34% of capital) - If drops 20%
#
# Average entry: $129.27
#
# RECOVERY POTENTIAL:
#   Target: $182.19 (52-week high)
#   Upside: +26.8%
#
# Analyzing MELI...
# ============================================================
# Fetching MELI data...
# Got 250 days of data
#
# CURRENT PRICE: $2016.75
# 52-Week High: $2548.50
# DRAWDOWN: -20.9% from highs
#
# QUALITY SCORE: 48/100
# Strengths:
#   + Adequate liquidity (CR 1.2)
#   + Marginally profitable (NM 7.9%)
#   + Strong margins (GM 50.4%)
#   + Strong growth (39.5% YoY)
# Warnings:
#   - WARNING: High debt (D/E 159)
#
# TECHNICAL STATUS:
#   RSI: 37 (Normal)
#   50-day MA: $2263.70
#   200-day MA: $2272.72
#
# RECOMMENDATION: AVOID
# Reason: Quality score too low (48/100) - survival risk
#
# Analyzing DASH...
# ============================================================
# Fetching DASH data...
# Got 250 days of data
#
# CURRENT PRICE: $200.11
# 52-Week High: $285.50
# DRAWDOWN: -29.9% from highs
#
# QUALITY SCORE: 75/100
# Strengths:
#   + Excellent liquidity (CR 2.0)
#   + Manageable debt (D/E 34)
#   + Marginally profitable (NM 6.8%)
#   + Strong margins (GM 51.4%)
#   + Strong growth (27.3% YoY)
#
# Valuation:
#   High P/E 101.1 (still expensive)
#
# TECHNICAL STATUS:
#   RSI: 21 (OVERSOLD)
#   50-day MA: $255.04
#   200-day MA: $223.29
#
# RECOMMENDATION: STRONG BUY (Crisis Opportunity)
# Reason: Quality company at panic prices
#
# DOLLAR-COST AVERAGE PLAN:
#   Entry 1: $200.11 (33% of capital) - BUY NOW
#   Entry 2: $180.10 (33% of capital) - If drops 10%
#   Entry 3: $160.09 (34% of capital) - If drops 20%
#
# Average entry: $180.10
#
# RECOVERY POTENTIAL:
#   Target: $285.50 (52-week high)
#   Upside: +42.7%
#
# Analyzing TSM...
# ============================================================
# Fetching TSM data...
# Got 250 days of data
#
# CURRENT PRICE: $281.39
# 52-Week High: $311.37
# DRAWDOWN: -9.6% from highs
#
# QUALITY SCORE: 90/100
# Strengths:
#   + Excellent liquidity (CR 2.7)
#   + Low debt (D/E 19)
#   + Highly profitable (NM 43.3%)
#   + Strong margins (GM 59.0%)
#   + Strong growth (30.3% YoY)
#
# Valuation:
#   Low P/B 1.5 (value)
#
# TECHNICAL STATUS:
#   RSI: 39 (Normal)
#   50-day MA: $284.47
#   200-day MA: $221.42
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-9.6% from high)
#
# Analyzing AMAT...
# ============================================================
# Fetching AMAT data...
# Got 250 days of data
#
# CURRENT PRICE: $216.51
# 52-Week High: $242.50
# DRAWDOWN: -10.7% from highs
#
# QUALITY SCORE: 75/100
# Strengths:
#   + Excellent liquidity (CR 2.5)
#   + Manageable debt (D/E 35)
#   + Highly profitable (NM 23.9%)
#   + Strong margins (GM 48.5%)
#   + Growing (7.7% YoY)
#
# TECHNICAL STATUS:
#   RSI: 42 (Normal)
#   50-day MA: $210.88
#   200-day MA: $177.13
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-10.7% from high)
#
# Analyzing LRCX...
# ============================================================
# Fetching LRCX data...
# Got 250 days of data
#
# CURRENT PRICE: $150.72
# 52-Week High: $167.15
# DRAWDOWN: -9.8% from highs
#
# QUALITY SCORE: 85/100
# Strengths:
#   + Excellent liquidity (CR 2.2)
#   + Manageable debt (D/E 44)
#   + Highly profitable (NM 29.7%)
#   + Strong margins (GM 49.3%)
#   + Strong growth (27.7% YoY)
#
# TECHNICAL STATUS:
#   RSI: 49 (Normal)
#   50-day MA: $139.73
#   200-day MA: $98.91
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-9.8% from high)
#
# Analyzing MRVL...
# ============================================================
# Fetching MRVL data...
# Got 250 days of data
#
# CURRENT PRICE: $87.06
# 52-Week High: $98.13
# DRAWDOWN: -11.3% from highs
#
# QUALITY SCORE: 65/100
# Strengths:
#   + Good liquidity (CR 1.9)
#   + Manageable debt (D/E 36)
#   + Strong margins (GM 49.6%)
#   + Strong growth (57.6% YoY)
# Warnings:
#   - WARNING: Unprofitable (NM -1.4%)
#
# TECHNICAL STATUS:
#   RSI: 54 (Normal)
#   50-day MA: $82.78
#   200-day MA: $75.54
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-11.3% from high)
#
# Analyzing UNH...
# ============================================================
# Fetching UNH data...
# Got 250 days of data
#
# CURRENT PRICE: $324.72
# 52-Week High: $381.00
# DRAWDOWN: -14.8% from highs
#
# QUALITY SCORE: 28/100
# Strengths:
#   + Marginally profitable (NM 4.0%)
#   + Good growth (12.2% YoY)
# Warnings:
#   - WARNING: Low liquidity (CR 0.8)
#   - Moderate debt (D/E 76)
#
# TECHNICAL STATUS:
#   RSI: 29 (OVERSOLD)
#   50-day MA: $347.12
#   200-day MA: $373.69
#
# RECOMMENDATION: AVOID
# Reason: Quality score too low (28/100) - survival risk
#
# Analyzing HIMS...
# ============================================================
# Fetching HIMS data...
# Got 250 days of data
#
# CURRENT PRICE: $36.56
# 52-Week High: $65.30
# DRAWDOWN: -44.0% from highs
#
# QUALITY SCORE: 55/100
# Strengths:
#   + Good liquidity (CR 1.9)
#   + Marginally profitable (NM 6.1%)
#   + Strong margins (GM 75.0%)
#   + Strong growth (49.2% YoY)
# Warnings:
#   - WARNING: High debt (D/E 192)
#
# Valuation:
#   High P/E 69.0 (still expensive)
#
# TECHNICAL STATUS:
#   RSI: 14 (OVERSOLD)
#   50-day MA: $50.86
#   200-day MA: $46.89
#
# RECOMMENDATION: AVOID
# Reason: Quality score too low (55/100) - survival risk
#
# Analyzing PLTR...
# ============================================================
# Fetching PLTR data...
# Got 250 days of data
#
# CURRENT PRICE: $170.92
# 52-Week High: $207.52
# DRAWDOWN: -17.6% from highs
#
# QUALITY SCORE: 90/100
# Strengths:
#   + Excellent liquidity (CR 6.4)
#   + Low debt (D/E 4)
#   + Highly profitable (NM 28.1%)
#   + Strong margins (GM 80.8%)
#   + Strong growth (62.8% YoY)
#
# Valuation:
#   High P/E 407.0 (still expensive)
#
# TECHNICAL STATUS:
#   RSI: 43 (Normal)
#   50-day MA: $180.03
#   200-day MA: $137.46
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-17.6% from high)
#
# Analyzing ADBE...
# ============================================================
# Fetching ADBE data...
# Got 250 days of data
#
# CURRENT PRICE: $329.60
# 52-Week High: $370.86
# DRAWDOWN: -11.1% from highs
#
# QUALITY SCORE: 61/100
# Strengths:
#   + Adequate liquidity (CR 1.0)
#   + Highly profitable (NM 30.0%)
#   + Strong margins (GM 89.1%)
#   + Good growth (10.7% YoY)
# Warnings:
#   - Moderate debt (D/E 57)
#
# TECHNICAL STATUS:
#   RSI: 31 (Normal)
#   50-day MA: $346.89
#   200-day MA: $378.98
#
# RECOMMENDATION: WAIT
# Reason: Quality company but not discounted enough (-11.1% from high)
#
# ============================================================
# CRISIS BUYING SUMMARY
# ============================================================
#
# STRONG BUY - Crisis Opportunities (4 stocks):
# Quality companies at panic prices - Start DCA now
#
#   COIN: $278.10 (Down -30.8%) - Upside: +44.6% [Quality: 85]
#     DCA: $278.10 -> $250.29 -> $222.48
#   DASH: $200.11 (Down -29.9%) - Upside: +42.7% [Quality: 75]
#     DCA: $200.11 -> $180.10 -> $160.09
#   META: $600.72 (Down -24.0%) - Upside: +31.6% [Quality: 85]
#     DCA: $600.72 -> $540.65 -> $480.58
#   SHOP: $143.63 (Down -21.2%) - Upside: +26.8% [Quality: 85]
#     DCA: $143.63 -> $129.27 -> $114.90
#
# WAIT - Not discounted enough (18 stocks):
#   MSFT: $502.05 (Down -9.3%) [Quality: 68]
#   GOOGL: $274.83 (Down -5.9%) [Quality: 80]
#   AMZN: $234.33 (Down -9.4%) [Quality: 63]
#   NVDA: $186.73 (Down -12.0%) [Quality: 90]
#   TSLA: $394.34 (Down -16.8%) [Quality: 60]
#   CRM: $238.10 (Down -10.9%) [Quality: 63]
#   NOW: $842.94 (Down -13.4%) [Quality: 73]
#   DDOG: $183.45 (Down -9.0%) [Quality: 75]
#   MDB: $346.97 (Down -10.0%) [Quality: 75]
#   CRWD: $525.81 (Down -7.2%) [Quality: 70]
#   V: $332.95 (Down -6.0%) [Quality: 61]
#   SOFI: $28.37 (Down -13.3%) [Quality: 68]
#   TSM: $281.39 (Down -9.6%) [Quality: 90]
#   AMAT: $216.51 (Down -10.7%) [Quality: 75]
#   LRCX: $150.72 (Down -9.8%) [Quality: 85]
#   MRVL: $87.06 (Down -11.3%) [Quality: 65]
#   PLTR: $170.92 (Down -17.6%) [Quality: 90]
#   ADBE: $329.60 (Down -11.1%) [Quality: 61]
#
# ============================================================
# CRISIS BUYING RULES:
# ============================================================
# 1. ONLY buy during bear markets/corrections
# 2. ONLY buy quality companies (score > 60)
# 3. ALWAYS dollar-cost average (3 entries)
# 4. Hold for 2-5 years (recovery + growth)
# 5. Size positions: 5-10% of portfolio max
# ============================================================

# %% [markdown]
# ## Single Stock Deep Dive

# %%
# Analyze specific stock in detail
ticker_to_analyze = 'NVDA'
result = analyze_for_crisis(ticker_to_analyze, fetcher)
